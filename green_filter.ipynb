# %% [markdown]
# # Init

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from astropy.io import fits
from astropy.visualization import simple_norm
import photutils
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.stats import SigmaClip
from photutils.background import Background2D, MedianBackground
from astropy.stats import sigma_clipped_stats, SigmaClip
from photutils.segmentation import detect_threshold, detect_sources
from photutils.utils import circular_footprint
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from photutils.segmentation import detect_sources
from scipy import stats
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS
from photutils.detection import DAOStarFinder
from astroquery.gaia import Gaia
import pandas as pd
import subprocess
import shutil
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from pathlib import Path
from scipy.stats import siegelslopes
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive

# %% [markdown]
# # Load files

# %%
observations_folder = r"/mnt/c/Users/catal/Downloads/unistellar_observations"

# List of all folders observation
observation_dirs = [d for d in os.listdir(observations_folder) 
                    if os.path.isdir(os.path.join(observations_folder, d))]
observation_dirs.sort()

print(f"Encontradas {len(observation_dirs)} observaciones para procesar\n")
print("=" * 60)


total_processed = 0
total_errors = 0

for obs_idx, obs_dir in enumerate(observation_dirs, 1):
    base_folder = os.path.join(observations_folder, obs_dir)
    dark_subtracted_folder = os.path.join(base_folder, "dark_subtracted")
    green_band_folder = os.path.join(base_folder, "green_band")
    
    # Verification if the folder exists
    if not os.path.exists(dark_subtracted_folder):
        print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
        print(f"  ⚠ No tiene carpeta 'dark_subtracted', saltando...\n")
        continue
    
    print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
    
    # Creation of new folder
    os.makedirs(green_band_folder, exist_ok=True)
    
    # Search for all .fits images
    fits_files = [f for f in os.listdir(dark_subtracted_folder) if f.endswith('.fits')]
    print(f"  Encontradas {len(fits_files)} imágenes")
    
    # Image processing
    for i, fits_file in enumerate(fits_files, 1):
        file_path = os.path.join(dark_subtracted_folder, fits_file)
        print(f"    [{i}/{len(fits_files)}] {fits_file}...", end=" ")
        
        try:
            # Opensfits file
            with fits.open(file_path) as hdul:
                header = hdul[0].header
                data = hdul[0].data.astype(float)
            
            wcs = WCS(header)
            
            # --------------------------------------------------
            # Green pattern (Bayern pattern RGGB)
            # Pixels in G band: (even row, odd col) y (odd row, even col)
            # --------------------------------------------------
            G = (data[0::2, 1::2] + data[1::2, 0::2]) / 2.0
            
            # --------------------------------------------------
            # FIX WCS (image size reduced by factor 2)
            # --------------------------------------------------
            wcs_green = wcs.deepcopy()
            
            if wcs_green.wcs.crpix is not None:
                wcs_green.wcs.crpix /= 2.0
            
            if wcs_green.wcs.cdelt is not None:
                wcs_green.wcs.cdelt *= 2.0
            
            # Update WCS keywords in the original header
            header.update(wcs_green.to_header())
            
            # Save image with green filter
            base_name = os.path.splitext(fits_file)[0]
            new_filename = os.path.join(green_band_folder, base_name + "_g_band.fits")
            
            hdu = fits.PrimaryHDU(G, header=header)
            hdu.writeto(new_filename, overwrite=True)
            
            print("✓")
            total_processed += 1
            
        except Exception as e:
            print(f"✗ Error: {str(e)}")
            total_errors += 1
    
    print()

print("=" * 60)
print(f"Procesamiento completado")
print(f"Total procesadas: {total_processed}")
print(f"Total errores: {total_errors}")
# Out:
# Encontradas 11 observaciones para procesar
#
# ============================================================
# [1/11] 20260202T180641_707
#   Encontradas 23 imágenes
#     [1/23] 20260202T180649_887_StackInput_DarkSubtracted.fits... ✓
#     [2/23] 20260202T180653_859_StackInput_DarkSubtracted.fits... ✓
#     [3/23] 20260202T180653_859_StackInput_DarkSubtracted_g_band.fits... ✓
#     [4/23] 20260202T180657_831_StackInput_DarkSubtracted.fits... ✓
#     [5/23] 20260202T180701_803_StackInput_DarkSubtracted.fits... ✓
#     [6/23] 20260202T180705_775_StackInput_DarkSubtracted.fits... ✓
#     [7/23] 20260202T180709_746_StackInput_DarkSubtracted.fits... ✓
#     [8/23] 20260202T180713_718_StackInput_DarkSubtracted.fits... ✓
#     [9/23] 20260202T180717_690_StackInput_DarkSubtracted.fits... ✓
#     [10/23] 20260202T180721_662_StackInput_DarkSubtracted.fits... ✓
#     [11/23] 20260202T180725_634_StackInput_DarkSubtracted.fits... ✓
#     [12/23] 20260202T180729_605_StackInput_DarkSubtracted.fits... ✓
#     [13/23] 20260202T180733_577_StackInput_DarkSubtracted.fits... ✓
#     [14/23] 20260202T180737_549_StackInput_DarkSubtracted.fits... ✓
#     [15/23] 20260202T180741_521_StackInput_DarkSubtracted.fits... ✓
#     [16/23] 20260202T180745_493_StackInput_DarkSubtracted.fits... ✓
#     [17/23] 20260202T180749_464_StackInput_DarkSubtracted.fits... ✓
#     [18/23] 20260202T180753_436_StackInput_DarkSubtracted.fits... ✓
#     [19/23] 20260202T180757_408_StackInput_DarkSubtracted.fits... ✓
#     [20/23] 20260202T180801_380_StackInput_DarkSubtracted.fits... ✓
#     [21/23] 20260202T180805_352_StackInput_DarkSubtracted.fits... ✓
#     [22/23] 20260202T180809_323_StackInput_DarkSubtracted.fits... ✓
#     [23/23] 20260202T180813_295_StackInput_DarkSubtracted.fits... ✓
#
# [2/11] 20260202T180839_175
#   Encontradas 2 imágenes
#     [1/2] 20260202T180847_356_StackInput_DarkSubtracted.fits... ✓
#     [2/2] 20260202T180851_328_StackInput_DarkSubtracted.fits... ✓
#
# [3/11] 20260202T180906_878
#   Encontradas 12 imágenes
#     [1/12] 20260202T180915_058_StackInput_DarkSubtracted.fits... ✓
#     [2/12] 20260202T180919_030_StackInput_DarkSubtracted.fits... ✓
#     [3/12] 20260202T180923_002_StackInput_DarkSubtracted.fits... ✓
#     [4/12] 20260202T180926_977_StackInput_DarkSubtracted.fits... ✓
#     [5/12] 20260202T180930_945_StackInput_DarkSubtracted.fits... ✓
#     [6/12] 20260202T180934_917_StackInput_DarkSubtracted.fits... ✓
#     [7/12] 20260202T180938_889_StackInput_DarkSubtracted.fits... ✓
#     [8/12] 20260202T180942_861_StackInput_DarkSubtracted.fits... ✓
#     [9/12] 20260202T180946_833_StackInput_DarkSubtracted.fits... ✓
#     [10/12] 20260202T180950_804_StackInput_DarkSubtracted.fits... ✓
#     [11/12] 20260202T180954_776_StackInput_DarkSubtracted.fits... ✓
#     [12/12] 20260202T180958_748_StackInput_DarkSubtracted.fits... ✓
#
# [4/11] 20260202T181050_173
#   Encontradas 12 imágenes
#     [1/12] 20260202T181058_353_StackInput_DarkSubtracted.fits... ✓
#     [2/12] 20260202T181102_325_StackInput_DarkSubtracted.fits... ✓
#     [3/12] 20260202T181106_297_StackInput_DarkSubtracted.fits... ✓
#     [4/12] 20260202T181110_269_StackInput_DarkSubtracted.fits... ✓
#     [5/12] 20260202T181114_241_StackInput_DarkSubtracted.fits... ✓
#     [6/12] 20260202T181118_212_StackInput_DarkSubtracted.fits... ✓
#     [7/12] 20260202T181122_184_StackInput_DarkSubtracted.fits... ✓
#     [8/12] 20260202T181126_156_StackInput_DarkSubtracted.fits... ✓
#     [9/12] 20260202T181130_128_StackInput_DarkSubtracted.fits... ✓
#     [10/12] 20260202T181134_100_StackInput_DarkSubtracted.fits... ✓
#     [11/12] 20260202T181138_071_StackInput_DarkSubtracted.fits... ✓
#     [12/12] 20260202T181142_043_StackInput_DarkSubtracted.fits... ✓
#
# [5/11] 20260202T181312_722
#   Encontradas 6 imágenes
#     [1/6] 20260202T181320_905_StackInput_DarkSubtracted.fits... ✓
#     [2/6] 20260202T181324_877_StackInput_DarkSubtracted.fits... ✓
#     [3/6] 20260202T181328_848_StackInput_DarkSubtracted.fits... ✓
#     [4/6] 20260202T181332_820_StackInput_DarkSubtracted.fits... ✓
#     [5/6] 20260202T181336_792_StackInput_DarkSubtracted.fits... ✓
#     [6/6] 20260202T181340_764_StackInput_DarkSubtracted.fits... ✓
#
# [6/11] 20260202T181402_092
#   Encontradas 13 imágenes
#     [1/13] 20260202T181410_275_StackInput_DarkSubtracted.fits... ✓
#     [2/13] 20260202T181414_247_StackInput_DarkSubtracted.fits... ✓
#     [3/13] 20260202T181418_219_StackInput_DarkSubtracted.fits... ✓
#     [4/13] 20260202T181422_191_StackInput_DarkSubtracted.fits... ✓
#     [5/13] 20260202T181426_163_StackInput_DarkSubtracted.fits... ✓
#     [6/13] 20260202T181430_134_StackInput_DarkSubtracted.fits... ✓
#     [7/13] 20260202T181434_106_StackInput_DarkSubtracted.fits... ✓
#     [8/13] 20260202T181438_078_StackInput_DarkSubtracted.fits... ✓
#     [9/13] 20260202T181442_050_StackInput_DarkSubtracted.fits... ✓
#     [10/13] 20260202T181446_022_StackInput_DarkSubtracted.fits... ✓
#     [11/13] 20260202T181449_993_StackInput_DarkSubtracted.fits... ✓
#     [12/13] 20260202T181453_965_StackInput_DarkSubtracted.fits... ✓
#     [13/13] 20260202T181457_937_StackInput_DarkSubtracted.fits... ✓
#
# [7/11] 20260202T181525_643
#   Encontradas 12 imágenes
#     [1/12] 20260202T181533_823_StackInput_DarkSubtracted.fits... ✓
#     [2/12] 20260202T181537_795_StackInput_DarkSubtracted.fits... ✓
#     [3/12] 20260202T181541_767_StackInput_DarkSubtracted.fits... ✓
#     [4/12] 20260202T181545_739_StackInput_DarkSubtracted.fits... ✓
#     [5/12] 20260202T181549_710_StackInput_DarkSubtracted.fits... ✓
#     [6/12] 20260202T181553_682_StackInput_DarkSubtracted.fits... ✓
#     [7/12] 20260202T181557_654_StackInput_DarkSubtracted.fits... ✓
#     [8/12] 20260202T181601_626_StackInput_DarkSubtracted.fits... ✓
#     [9/12] 20260202T181605_598_StackInput_DarkSubtracted.fits... ✓
#     [10/12] 20260202T181609_569_StackInput_DarkSubtracted.fits... ✓
#     [11/12] 20260202T181613_541_StackInput_DarkSubtracted.fits... ✓
#     [12/12] 20260202T181617_513_StackInput_DarkSubtracted.fits... ✓
#
# [8/11] 20260202T181730_106
#   Encontradas 14 imágenes
#     [1/14] 20260202T181738_287_StackInput_DarkSubtracted.fits... ✓
#     [2/14] 20260202T181742_259_StackInput_DarkSubtracted.fits... ✓
#     [3/14] 20260202T181746_230_StackInput_DarkSubtracted.fits... ✓
#     [4/14] 20260202T181750_202_StackInput_DarkSubtracted.fits... ✓
#     [5/14] 20260202T181754_174_StackInput_DarkSubtracted.fits... ✓
#     [6/14] 20260202T181758_146_StackInput_DarkSubtracted.fits... ✓
#     [7/14] 20260202T181802_118_StackInput_DarkSubtracted.fits... ✓
#     [8/14] 20260202T181806_089_StackInput_DarkSubtracted.fits... ✓
#     [9/14] 20260202T181810_061_StackInput_DarkSubtracted.fits... ✓
#     [10/14] 20260202T181814_033_StackInput_DarkSubtracted.fits... ✓
#     [11/14] 20260202T181818_005_StackInput_DarkSubtracted.fits... ✓
#     [12/14] 20260202T181821_977_StackInput_DarkSubtracted.fits... ✓
#     [13/14] 20260202T181825_948_StackInput_DarkSubtracted.fits... ✓
#     [14/14] 20260202T181829_920_StackInput_DarkSubtracted.fits... ✓
#
# [9/11] 20260202T181856_216
#   Encontradas 13 imágenes
#     [1/13] 20260202T181904_400_StackInput_DarkSubtracted.fits... ✓
#     [2/13] 20260202T181908_371_StackInput_DarkSubtracted.fits... ✓
#     [3/13] 20260202T181912_343_StackInput_DarkSubtracted.fits... ✓
#     [4/13] 20260202T181916_315_StackInput_DarkSubtracted.fits... ✓
#     [5/13] 20260202T181920_287_StackInput_DarkSubtracted.fits... ✓
#     [6/13] 20260202T181924_259_StackInput_DarkSubtracted.fits... ✓
#     [7/13] 20260202T181928_230_StackInput_DarkSubtracted.fits... ✓
#     [8/13] 20260202T181932_202_StackInput_DarkSubtracted.fits... ✓
#     [9/13] 20260202T181936_174_StackInput_DarkSubtracted.fits... ✓
#     [10/13] 20260202T181940_146_StackInput_DarkSubtracted.fits... ✓
#     [11/13] 20260202T181944_118_StackInput_DarkSubtracted.fits... ✓
#     [12/13] 20260202T181948_089_StackInput_DarkSubtracted.fits... ✓
#     [13/13] 20260202T181952_061_StackInput_DarkSubtracted.fits... ✓
#
# [10/11] 20260202T182019_864
#   Encontradas 26 imágenes
#     [1/26] 20260202T182028_047_StackInput_DarkSubtracted.fits... ✓
#     [2/26] 20260202T182032_019_StackInput_DarkSubtracted.fits... ✓
#     [3/26] 20260202T182035_990_StackInput_DarkSubtracted.fits... ✓
#     [4/26] 20260202T182039_962_StackInput_DarkSubtracted.fits... ✓
#     [5/26] 20260202T182043_934_StackInput_DarkSubtracted.fits... ✓
#     [6/26] 20260202T182047_906_StackInput_DarkSubtracted.fits... ✓
#     [7/26] 20260202T182051_878_StackInput_DarkSubtracted.fits... ✓
#     [8/26] 20260202T182055_849_StackInput_DarkSubtracted.fits... ✓
#     [9/26] 20260202T182059_821_StackInput_DarkSubtracted.fits... ✓
#     [10/26] 20260202T182103_793_StackInput_DarkSubtracted.fits... ✓
#     [11/26] 20260202T182107_765_StackInput_DarkSubtracted.fits... ✓
#     [12/26] 20260202T182111_737_StackInput_DarkSubtracted.fits... ✓
#     [13/26] 20260202T182115_708_StackInput_DarkSubtracted.fits... ✓
#     [14/26] 20260202T182119_680_StackInput_DarkSubtracted.fits... ✓
#     [15/26] 20260202T182123_652_StackInput_DarkSubtracted.fits... ✓
#     [16/26] 20260202T182127_624_StackInput_DarkSubtracted.fits... ✓
#     [17/26] 20260202T182131_596_StackInput_DarkSubtracted.fits... ✓
#     [18/26] 20260202T182135_567_StackInput_DarkSubtracted.fits... ✓
#     [19/26] 20260202T182139_539_StackInput_DarkSubtracted.fits... ✓
#     [20/26] 20260202T182143_511_StackInput_DarkSubtracted.fits... ✓
#     [21/26] 20260202T182147_483_StackInput_DarkSubtracted.fits... ✓
#     [22/26] 20260202T182151_455_StackInput_DarkSubtracted.fits... ✓
#     [23/26] 20260202T182155_426_StackInput_DarkSubtracted.fits... ✓
#     [24/26] 20260202T182159_398_StackInput_DarkSubtracted.fits... ✓
#     [25/26] 20260202T182203_370_StackInput_DarkSubtracted.fits... ✓
#     [26/26] 20260202T182207_342_StackInput_DarkSubtracted.fits... ✓
#
# [11/11] 20260202T182405_275
#   Encontradas 6 imágenes
#     [1/6] 20260202T182413_456_StackInput_DarkSubtracted.fits... ✓
#     [2/6] 20260202T182413_456_StackInput_DarkSubtracted_g_band.fits... ✓
#     [3/6] 20260202T182417_427_StackInput_DarkSubtracted.fits... ✓
#     [4/6] 20260202T182421_399_StackInput_DarkSubtracted.fits... ✓
#     [5/6] 20260202T182425_371_StackInput_DarkSubtracted.fits... ✓
#     [6/6] 20260202T182429_343_StackInput_DarkSubtracted.fits... ✓
#
# ============================================================
# Procesamiento completado
# Total procesadas: 139
# Total errores: 0

# %% [markdown]
# ## Red Band Extraction (RGGB Bayer Pattern)

# %%
observations_folder = r"/mnt/c/Users/catal/Downloads/unistellar_observations"

# List of all folders observation
observation_dirs = [d for d in os.listdir(observations_folder) 
                    if os.path.isdir(os.path.join(observations_folder, d))]
observation_dirs.sort()

print(f"Encontradas {len(observation_dirs)} observaciones para procesar\n")
print("=" * 60)


total_processed = 0
total_errors = 0

for obs_idx, obs_dir in enumerate(observation_dirs, 1):
    base_folder = os.path.join(observations_folder, obs_dir)
    dark_subtracted_folder = os.path.join(base_folder, "dark_subtracted")
    red_band_folder = os.path.join(base_folder, "red_band")
    
    # Verification if the folder exists
    if not os.path.exists(dark_subtracted_folder):
        print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
        print(f"  ⚠ No tiene carpeta 'dark_subtracted', saltando...\n")
        continue
    
    print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
    
    # Creation of new folder
    os.makedirs(red_band_folder, exist_ok=True)
    
    # Search for all .fits images
    fits_files = [f for f in os.listdir(dark_subtracted_folder) if f.endswith('.fits')]
    print(f"  Encontradas {len(fits_files)} imágenes")
    
    # Image processing
    for i, fits_file in enumerate(fits_files, 1):
        file_path = os.path.join(dark_subtracted_folder, fits_file)
        print(f"    [{i}/{len(fits_files)}] {fits_file}...", end=" ")
        
        try:
            # Open fits file
            with fits.open(file_path) as hdul:
                header = hdul[0].header
                data = hdul[0].data.astype(float)
            
            wcs = WCS(header)
            
            # --------------------------------------------------
            # Red pattern (Bayern pattern RGGB)
            # Red pixels: (even row, even col)
            # --------------------------------------------------
            R = data[0::2, 0::2]
            
            # --------------------------------------------------
            # FIX WCS (image size reduced by factor 2)
            # --------------------------------------------------
            wcs_red = wcs.deepcopy()
            
            if wcs_red.wcs.crpix is not None:
                wcs_red.wcs.crpix /= 2.0
            
            if wcs_red.wcs.cdelt is not None:
                wcs_red.wcs.cdelt *= 2.0
            
            # Update WCS keywords in the original header
            header.update(wcs_red.to_header())
            
            # Save image with red filter
            base_name = os.path.splitext(fits_file)[0]
            new_filename = os.path.join(red_band_folder, base_name + "_r_band.fits")
            
            hdu = fits.PrimaryHDU(R, header=header)
            hdu.writeto(new_filename, overwrite=True)
            
            print("✓")
            total_processed += 1
            
        except Exception as e:
            print(f"✗ Error: {str(e)}")
            total_errors += 1
    
    print()

print("=" * 60)
print(f"Procesamiento completado")
print(f"Total procesadas: {total_processed}")
print(f"Total errores: {total_errors}")

# %% [markdown]
# ## Blue Band Extraction (RGGB Bayer Pattern)

# %%
observations_folder = r"/mnt/c/Users/catal/Downloads/unistellar_observations"

# List of all folders observation
observation_dirs = [d for d in os.listdir(observations_folder) 
                    if os.path.isdir(os.path.join(observations_folder, d))]
observation_dirs.sort()

print(f"Encontradas {len(observation_dirs)} observaciones para procesar\n")
print("=" * 60)


total_processed = 0
total_errors = 0

for obs_idx, obs_dir in enumerate(observation_dirs, 1):
    base_folder = os.path.join(observations_folder, obs_dir)
    dark_subtracted_folder = os.path.join(base_folder, "dark_subtracted")
    blue_band_folder = os.path.join(base_folder, "blue_band")
    
    # Verification if the folder exists
    if not os.path.exists(dark_subtracted_folder):
        print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
        print(f"  ⚠ No tiene carpeta 'dark_subtracted', saltando...\n")
        continue
    
    print(f"[{obs_idx}/{len(observation_dirs)}] {obs_dir}")
    
    # Creation of new folder
    os.makedirs(blue_band_folder, exist_ok=True)
    
    # Search for all .fits images
    fits_files = [f for f in os.listdir(dark_subtracted_folder) if f.endswith('.fits')]
    print(f"  Encontradas {len(fits_files)} imágenes")
    
    # Image processing
    for i, fits_file in enumerate(fits_files, 1):
        file_path = os.path.join(dark_subtracted_folder, fits_file)
        print(f"    [{i}/{len(fits_files)}] {fits_file}...", end=" ")
        
        try:
            # Open fits file
            with fits.open(file_path) as hdul:
                header = hdul[0].header
                data = hdul[0].data.astype(float)
            
            wcs = WCS(header)
            
            # --------------------------------------------------
            # Blue pattern (Bayern pattern RGGB)
            # Blue pixels: (odd row, odd col)
            # --------------------------------------------------
            B = data[1::2, 1::2]
            
            # --------------------------------------------------
            # FIX WCS (image size reduced by factor 2)
            # --------------------------------------------------
            wcs_blue = wcs.deepcopy()
            
            if wcs_blue.wcs.crpix is not None:
                wcs_blue.wcs.crpix /= 2.0
            
            if wcs_blue.wcs.cdelt is not None:
                wcs_blue.wcs.cdelt *= 2.0
            
            # Update WCS keywords in the original header
            header.update(wcs_blue.to_header())
            
            # Save image with blue filter
            base_name = os.path.splitext(fits_file)[0]
            new_filename = os.path.join(blue_band_folder, base_name + "_b_band.fits")
            
            hdu = fits.PrimaryHDU(B, header=header)
            hdu.writeto(new_filename, overwrite=True)
            
            print("✓")
            total_processed += 1
            
        except Exception as e:
            print(f"✗ Error: {str(e)}")
            total_errors += 1
    
    print()

print("=" * 60)
print(f"Procesamiento completado")
print(f"Total procesadas: {total_processed}")
print(f"Total errores: {total_errors}")
